# %%
import pandas as pd
pd.options.display.max_columns = None
pd.set_option('display.max_rows', 20)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from keras.models import Model, Sequential
from keras.layers import Dense, Input
from sklearn.metrics import mean_squared_error, r2_score

# %%
df_regression = pd.read_excel("feature-eng-data/novel_regression_dataset.xlsx")
df_regression = df_regression.drop(df_regression.columns[0], axis=1)
df_regression = df_regression.set_index("CompanyNumber")

# %%
df_regression
# Out:
#                AssetsM     TurnoverM      FTE  IR_CO2ePerAssetsM  \
# CompanyNumber
# 00019457        3152.0    603.300000   3152.0           0.060444
# 00024869        1048.0    486.000000   1048.0           0.253968
# 00029559       76060.0    291.200000  76060.0         516.260563
# 00030226         584.0    104.600000    584.0         473.260870
# 00033774        4017.0  15700.000000   4017.0        1866.017132
# ...                ...           ...      ...                ...
# SC334329         381.0     37.473996    381.0          61.967019
# SC367563        1125.0    108.500000   1125.0           5.116468
# SC419949           0.0     29.375452      0.0          20.503251
# SC440783        1330.0    498.237572   1330.0        9889.035686
# SC578050           0.0     99.051884      0.0          16.295030
#
#                IR_CO2ePerTurnoverM  IR_CO2ePerFTE  DefraRatio  \
# CompanyNumber
# 00019457                  0.078988       0.015111      1.3750
# 00024869                  0.954733       0.442748      0.0375
# 00029559                755.762887       2.891494      0.3750
# 00030226                373.200000      67.099315      6.6250
# 00033774                319.124586    1247.263132      3.8750
# ...                            ...            ...         ...
# SC334329                 33.135135       3.217848      0.0375
# SC367563                 25.995413       2.518667      0.3750
# SC419949                 28.137931       0.000000      0.0375
# SC440783                 25.656627       9.606767      2.6250
# SC578050                  1.242424       0.000000      1.2500
#
#                NormalisedIrCO2ePerAssetsM  NormalisedIrCO2ePerTurnoverM  \
# CompanyNumber
# 00019457                        88.414665                        39.608
# 00024869                        88.414665                        39.608
# 00029559                        88.414665                        39.608
# 00030226                        88.414665                        39.608
# 00033774                        88.414665                        39.608
# ...                                   ...                           ...
# SC334329                        88.414665                        39.608
# SC367563                        88.414665                        39.608
# SC419949                        88.414665                        39.608
# SC440783                        88.414665                        39.608
# SC578050                        88.414665                        39.608
#
#                NormalisedIrCO2ePerFTE  ScoreC1a  ScoreC1t  ScoreC1f  ScoreC2  \
# CompanyNumber
# 00019457                     7.726939        10      10.0  9.000000      9.0
# 00024869                     7.726939        10       9.0  8.000000      6.0
# 00029559                     7.726939         2       1.0  5.000000      2.0
# 00030226                     7.726939         2       2.0  2.000000      5.0
# 00033774                     7.726939         1       2.0  1.000000      2.0
# ...                               ...       ...       ...       ...      ...
# SC334329                     7.726939         5       5.0  5.000000      2.0
# SC367563                     7.726939         8       5.0  5.000000      6.0
# SC419949                     7.726939         7       5.0  5.195021      2.0
# SC440783                     7.726939         1       5.0  3.000000      5.0
# SC578050                     7.726939         7       9.0  5.195021      9.0
#
#                ScoreC1   S1S2CO2e
# CompanyNumber
# 00019457           9.0      47.63
# 00024869           9.0     269.00
# 00029559           2.0  219927.00
# 00030226           2.0   39186.00
# 00033774           1.0  431311.00
# ...                ...        ...
# SC334329           5.0       0.00
# SC367563           6.0    2272.20
# SC419949           6.0     771.00
# SC440783           3.0   12715.00
# SC578050           8.0     123.00
#
# [765 rows x 16 columns]

# %%
features_list = df_regression.columns

# %% [markdown]
# Regressor with 15 features

# %%
scaler = MinMaxScaler()
normalised_df_regression = scaler.fit_transform(df_regression)
S1S2CO2e = normalised_df_regression[:, -1]

# drop the label
normalised_df_regression = np.delete(normalised_df_regression, -1, axis=1)

# %%
normalised_df_regression.shape
# Out:
# (765, 15)

# %%
# Split training data and test data
X = normalised_df_regression
Y = S1S2CO2e

X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.70, test_size=0.30, random_state=0)

print('Number of instances in X: {}'.format(np.shape(X)[0]))
print('Number of instances in X_train: {}'.format(X_train.shape[0]))
print('Number of instances in X_test: {}'.format(X_test.shape[0]))
print('Number of instances in X_train and X_test together: {}'.format(X_train.shape[0] + X_test.shape[0]))
# Out:
# Number of instances in X: 765
# Number of instances in X_train: 535
# Number of instances in X_test: 230
# Number of instances in X_train and X_test together: 765

# %%
# Define input layer
input_layer = Input(shape=(X_train.shape[1],))
latent_feature = 1

# Encoder layers
encoder_layer1 = Dense(64, activation='relu')(input_layer)
encoder_layer2 = Dense(32, activation='relu')(encoder_layer1)
encoder_output = Dense(latent_feature, activation='relu')(encoder_layer2)  # Latent view

# Decoder layers
decoder_layer1 = Dense(32, activation='relu')(encoder_output)
decoder_layer2 = Dense(64, activation='relu')(decoder_layer1)
decoder_output = Dense(X_train.shape[1], activation='sigmoid')(decoder_layer2)

# Compile the autoencoder
autoencoder = Model(inputs=input_layer, outputs=decoder_output)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

autoencoder.fit(X_train, X_train, epochs=100, batch_size=32, validation_data=(X_test, X_test), verbose=0)

encoder = Model(inputs=input_layer, outputs=encoder_output)
encoded_data = encoder.predict(X_train)
encoded_data_test = encoder.predict(X_test)

combined_encoded_data = np.concatenate([encoded_data, encoded_data_test], axis=0)
X_with_ae = np.concatenate([normalised_df_regression, combined_encoded_data], axis=1)
X_with_ae.shape
# Out:
# 17/17 [==============================] - 0s 245us/step
# 8/8 [==============================] - 0s 440us/step
# (765, 16)

# %%
df_regression = pd.read_excel("feature-eng-data/regression_dataset.xlsx")
df_regression = df_regression.drop(df_regression.columns[0], axis=1)
df_regression = df_regression.set_index("CompanyNumber")

scaler = MinMaxScaler()
normalised_df_regression = scaler.fit_transform(df_regression)
S1S2CO2e = normalised_df_regression[:, -1]

# drop the label
normalised_df_regression = np.delete(normalised_df_regression, -1, axis=1)

combined_encoded_data = np.concatenate([encoded_data, encoded_data_test], axis=0)
X_with_ae = np.concatenate([normalised_df_regression, combined_encoded_data], axis=1)
X_with_ae.shape
# Out:
# (765, 40)

# %%
def plot_regressors(X, y):
    
    models = [
        LinearRegression(),
        DecisionTreeRegressor(random_state=0),
        RandomForestRegressor(random_state=0),
        XGBRegressor(random_state=0)
    ]
    
    # Define ANN model
    def build_ann():
        model = Sequential()
        model.add(Dense(units=16, activation='relu', input_shape=(X.shape[1],)))
        model.add(Dense(units=8, activation='relu'))
        model.add(Dense(units=1))
        model.compile(optimizer='adam', loss='mean_squared_error')
        return model
    
    models.append(build_ann())
    
    names = ["Linear Regression", "Decision Tree", "Random Forest", "XGBoost", "ANN"]

    entries_train = []
    entries_test = []

    kf = KFold(n_splits=10, shuffle=False)

    for train_index, test_index in kf.split(X):
        
        X_train_fold, X_test_fold = X[train_index], X[test_index]
        y_train_fold, y_test_fold = y[train_index], y[test_index]

        for idx, model in enumerate(models):
            model_name = names[idx]

            # Train the ANN model
            if model_name == "ANN":
                model.fit(X_train_fold, y_train_fold, epochs=50, verbose=0, batch_size=32)
            else:
                model.fit(X_train_fold, y_train_fold)
                
            y_train_pred_fold = model.predict(X_train_fold)

            # RMSE and R2 score on training set
            train_rmse = np.sqrt(mean_squared_error(y_train_pred_fold, y_train_fold))
            r2_train = r2_score(y_train_pred_fold, y_train_fold)
            entries_train.append((model_name, train_rmse, r2_train))
            train_scores = pd.DataFrame(entries_train, columns=["Model name", "Train RMSE", "Train R2-Score"])
            
            y_test_pred_fold = model.predict(X_test_fold)

            # RMSE and R2 score on the test set
            test_rmse = np.sqrt(mean_squared_error(y_test_pred_fold, y_test_fold))
            r2_test = r2_score(y_test_pred_fold, y_test_fold)
            entries_test.append((model_name, test_rmse, r2_test))
            test_scores = pd.DataFrame(entries_test, columns=["Model name", "Test RMSE", "Test R2-Score"])

    # Getting the test RMSE values for each model
    test_scores_LR = test_scores[test_scores['Model name'] == 'Linear Regression']['Test RMSE'].values.tolist()
    test_scores_DT = test_scores[test_scores['Model name'] == 'Decision Tree']['Test RMSE'].values.tolist()
    test_scores_RF = test_scores[test_scores['Model name'] == 'Random Forest']['Test RMSE'].values.tolist()
    test_scores_XGB = test_scores[test_scores['Model name'] == 'XGBoost']['Test RMSE'].values.tolist()
    test_scores_ANN = test_scores[test_scores['Model name'] == 'ANN']['Test RMSE'].values.tolist()
    test_rmse = [test_scores_LR, test_scores_DT, test_scores_RF, test_scores_XGB, test_scores_ANN]

    fig, ax = plt.subplots(figsize=(15,8))
    sns.boxplot(data=test_rmse)
    plt.xticks(range(len(test_rmse)), names)
    plt.xlabel('Model')
    plt.title('Test RMSE')
    plt.ylabel('RMSE')
    plt.grid(alpha=0.6)
    plt.show()

    train_and_test_df = pd.merge(train_scores.groupby('Model name').mean(), test_scores.groupby('Model name').mean(), on = 'Model name', how = 'outer')
    print("RMSE and R2 Scores")
    print(train_and_test_df)

plot_regressors(X_with_ae, Y)
# Out:
# 22/22 [==============================] - 0s 245us/step
# 3/3 [==============================] - 0s 494us/step
# 22/22 [==============================] - 0s 226us/step
# 3/3 [==============================] - 0s 510us/step
# 22/22 [==============================] - 0s 233us/step
# 3/3 [==============================] - 0s 495us/step
# 22/22 [==============================] - 0s 223us/step
# 3/3 [==============================] - 0s 711us/step
# 22/22 [==============================] - 0s 211us/step
# 3/3 [==============================] - 0s 652us/step
# 22/22 [==============================] - 0s 214us/step
# 3/3 [==============================] - 0s 512us/step
# 22/22 [==============================] - 0s 215us/step
# 3/3 [==============================] - 0s 533us/step
# 22/22 [==============================] - 0s 238us/step
# 3/3 [==============================] - 0s 613us/step
# 22/22 [==============================] - 0s 222us/step
# 3/3 [==============================] - 0s 904us/step
# 22/22 [==============================] - 0s 225us/step
# 3/3 [==============================] - 0s 753us/step
# RMSE and R2 Scores
#                      Train RMSE  Train R2-Score  Test RMSE  Test R2-Score
# Model name
# ANN                9.242573e-02        0.172028   0.101566      -0.699845
# Decision Tree      2.907995e-10        1.000000   0.138607      -0.429699
# Linear Regression  1.096431e-01       -0.465613   0.118697      -1.470011
# Random Forest      3.963735e-02        0.892180   0.101620      -0.124699
# XGBoost            1.226134e-03        0.999925   0.107885       0.001622

# %%
# Define input layer
input_layer = Input(shape=(X_train.shape[1],))
latent_feature = 2

# Encoder layers
encoder_layer1 = Dense(64, activation='relu')(input_layer)
encoder_layer2 = Dense(32, activation='relu')(encoder_layer1)
encoder_output = Dense(latent_feature, activation='relu')(encoder_layer2)  # Latent view

# Decoder layers
decoder_layer1 = Dense(32, activation='relu')(encoder_output)
decoder_layer2 = Dense(64, activation='relu')(decoder_layer1)
decoder_output = Dense(X_train.shape[1], activation='sigmoid')(decoder_layer2)

# Compile the autoencoder
autoencoder = Model(inputs=input_layer, outputs=decoder_output)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

autoencoder.fit(X_train, X_train, epochs=100, batch_size=32, validation_data=(X_test, X_test), verbose=0)

encoder = Model(inputs=input_layer, outputs=encoder_output)
encoded_data = encoder.predict(X_train)
encoded_data_test = encoder.predict(X_test)

combined_encoded_data = np.concatenate([encoded_data, encoded_data_test], axis=0)
X_with_ae = np.concatenate([normalised_df_regression, combined_encoded_data], axis=1)
X_with_ae.shape

def plot_regressors(X, y):
    
    models = [
        LinearRegression(),
        DecisionTreeRegressor(random_state=0),
        RandomForestRegressor(random_state=0),
        XGBRegressor(random_state=0)
    ]
    
    # Define ANN model
    def build_ann():
        model = Sequential()
        model.add(Dense(units=16, activation='relu', input_shape=(X.shape[1],)))
        model.add(Dense(units=8, activation='relu'))
        model.add(Dense(units=1))
        model.compile(optimizer='adam', loss='mean_squared_error')
        return model
    
    models.append(build_ann())
    
    names = ["Linear Regression", "Decision Tree", "Random Forest", "XGBoost", "ANN"]

    entries_train = []
    entries_test = []

    kf = KFold(n_splits=10, shuffle=False)

    for train_index, test_index in kf.split(X):
        
        X_train_fold, X_test_fold = X[train_index], X[test_index]
        y_train_fold, y_test_fold = y[train_index], y[test_index]

        for idx, model in enumerate(models):
            model_name = names[idx]

            # Train the ANN model
            if model_name == "ANN":
                model.fit(X_train_fold, y_train_fold, epochs=50, verbose=0, batch_size=32)
            else:
                model.fit(X_train_fold, y_train_fold)
                
            y_train_pred_fold = model.predict(X_train_fold)

            # RMSE and R2 score on training set
            train_rmse = np.sqrt(mean_squared_error(y_train_pred_fold, y_train_fold))
            r2_train = r2_score(y_train_pred_fold, y_train_fold)
            entries_train.append((model_name, train_rmse, r2_train))
            train_scores = pd.DataFrame(entries_train, columns=["Model name", "Train RMSE", "Train R2-Score"])
            
            y_test_pred_fold = model.predict(X_test_fold)

            # RMSE and R2 score on the test set
            test_rmse = np.sqrt(mean_squared_error(y_test_pred_fold, y_test_fold))
            r2_test = r2_score(y_test_pred_fold, y_test_fold)
            entries_test.append((model_name, test_rmse, r2_test))
            test_scores = pd.DataFrame(entries_test, columns=["Model name", "Test RMSE", "Test R2-Score"])

    # Getting the test RMSE values for each model
    test_scores_LR = test_scores[test_scores['Model name'] == 'Linear Regression']['Test RMSE'].values.tolist()
    test_scores_DT = test_scores[test_scores['Model name'] == 'Decision Tree']['Test RMSE'].values.tolist()
    test_scores_RF = test_scores[test_scores['Model name'] == 'Random Forest']['Test RMSE'].values.tolist()
    test_scores_XGB = test_scores[test_scores['Model name'] == 'XGBoost']['Test RMSE'].values.tolist()
    test_scores_ANN = test_scores[test_scores['Model name'] == 'ANN']['Test RMSE'].values.tolist()
    test_rmse = [test_scores_LR, test_scores_DT, test_scores_RF, test_scores_XGB, test_scores_ANN]

    fig, ax = plt.subplots(figsize=(15,8))
    sns.boxplot(data=test_rmse)
    plt.xticks(range(len(test_rmse)), names)
    plt.xlabel('Model')
    plt.title('Test RMSE')
    plt.ylabel('RMSE')
    plt.grid(alpha=0.6)
    plt.show()

    train_and_test_df = pd.merge(train_scores.groupby('Model name').mean(), test_scores.groupby('Model name').mean(), on = 'Model name', how = 'outer')
    print("RMSE and R2 Scores")
    print(train_and_test_df)

plot_regressors(X_with_ae, Y)
# Out:
# 17/17 [==============================] - 0s 254us/step
# 8/8 [==============================] - 0s 277us/step
# 22/22 [==============================] - 0s 237us/step
# 3/3 [==============================] - 0s 499us/step
# 22/22 [==============================] - 0s 230us/step
# 3/3 [==============================] - 0s 505us/step
# 22/22 [==============================] - 0s 229us/step
# 3/3 [==============================] - 0s 495us/step
# 22/22 [==============================] - 0s 226us/step
# 3/3 [==============================] - 0s 423us/step
# 22/22 [==============================] - 0s 214us/step
# 3/3 [==============================] - 0s 446us/step
# 22/22 [==============================] - 0s 222us/step
# 3/3 [==============================] - 0s 460us/step
# 22/22 [==============================] - 0s 214us/step
# 3/3 [==============================] - 0s 457us/step
# 22/22 [==============================] - 0s 221us/step
# 3/3 [==============================] - 0s 499us/step
# 22/22 [==============================] - 0s 213us/step
# 3/3 [==============================] - 0s 449us/step
# 22/22 [==============================] - 0s 218us/step
# 3/3 [==============================] - 0s 467us/step
# RMSE and R2 Scores
#                      Train RMSE  Train R2-Score  Test RMSE  Test R2-Score
# Model name
# ANN                1.037071e-01       -0.348537   0.105128      -1.151613
# Decision Tree      2.907995e-10        1.000000   0.151874      -0.699260
# Linear Regression  1.172638e-01       -1.117548   0.121208      -1.940362
# Random Forest      4.053157e-02        0.886225   0.099937      -0.081171
# XGBoost            1.225155e-03        0.999925   0.114353      -0.305640

# %%
# Define input layer
input_layer = Input(shape=(X_train.shape[1],))
latent_feature = 3

# Encoder layers
encoder_layer1 = Dense(64, activation='relu')(input_layer)
encoder_layer2 = Dense(32, activation='relu')(encoder_layer1)
encoder_output = Dense(latent_feature, activation='relu')(encoder_layer2)  # Latent view

# Decoder layers
decoder_layer1 = Dense(32, activation='relu')(encoder_output)
decoder_layer2 = Dense(64, activation='relu')(decoder_layer1)
decoder_output = Dense(X_train.shape[1], activation='sigmoid')(decoder_layer2)

# Compile the autoencoder
autoencoder = Model(inputs=input_layer, outputs=decoder_output)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

autoencoder.fit(X_train, X_train, epochs=100, batch_size=32, validation_data=(X_test, X_test), verbose=0)

encoder = Model(inputs=input_layer, outputs=encoder_output)
encoded_data = encoder.predict(X_train)
encoded_data_test = encoder.predict(X_test)

combined_encoded_data = np.concatenate([encoded_data, encoded_data_test], axis=0)
X_with_ae = np.concatenate([normalised_df_regression, combined_encoded_data], axis=1)
X_with_ae.shape

def plot_regressors(X, y):
    
    models = [
        LinearRegression(),
        DecisionTreeRegressor(random_state=0),
        RandomForestRegressor(random_state=0),
        XGBRegressor(random_state=0)
    ]
    
    # Define ANN model
    def build_ann():
        model = Sequential()
        model.add(Dense(units=16, activation='relu', input_shape=(X.shape[1],)))
        model.add(Dense(units=8, activation='relu'))
        model.add(Dense(units=1))
        model.compile(optimizer='adam', loss='mean_squared_error')
        return model
    
    models.append(build_ann())
    
    names = ["Linear Regression", "Decision Tree", "Random Forest", "XGBoost", "ANN"]

    entries_train = []
    entries_test = []

    kf = KFold(n_splits=10, shuffle=False)

    for train_index, test_index in kf.split(X):
        
        X_train_fold, X_test_fold = X[train_index], X[test_index]
        y_train_fold, y_test_fold = y[train_index], y[test_index]

        for idx, model in enumerate(models):
            model_name = names[idx]

            # Train the ANN model
            if model_name == "ANN":
                model.fit(X_train_fold, y_train_fold, epochs=50, verbose=0, batch_size=32)
            else:
                model.fit(X_train_fold, y_train_fold)
                
            y_train_pred_fold = model.predict(X_train_fold)

            # RMSE and R2 score on training set
            train_rmse = np.sqrt(mean_squared_error(y_train_pred_fold, y_train_fold))
            r2_train = r2_score(y_train_pred_fold, y_train_fold)
            entries_train.append((model_name, train_rmse, r2_train))
            train_scores = pd.DataFrame(entries_train, columns=["Model name", "Train RMSE", "Train R2-Score"])
            
            y_test_pred_fold = model.predict(X_test_fold)

            # RMSE and R2 score on the test set
            test_rmse = np.sqrt(mean_squared_error(y_test_pred_fold, y_test_fold))
            r2_test = r2_score(y_test_pred_fold, y_test_fold)
            entries_test.append((model_name, test_rmse, r2_test))
            test_scores = pd.DataFrame(entries_test, columns=["Model name", "Test RMSE", "Test R2-Score"])

    # Getting the test RMSE values for each model
    test_scores_LR = test_scores[test_scores['Model name'] == 'Linear Regression']['Test RMSE'].values.tolist()
    test_scores_DT = test_scores[test_scores['Model name'] == 'Decision Tree']['Test RMSE'].values.tolist()
    test_scores_RF = test_scores[test_scores['Model name'] == 'Random Forest']['Test RMSE'].values.tolist()
    test_scores_XGB = test_scores[test_scores['Model name'] == 'XGBoost']['Test RMSE'].values.tolist()
    test_scores_ANN = test_scores[test_scores['Model name'] == 'ANN']['Test RMSE'].values.tolist()
    test_rmse = [test_scores_LR, test_scores_DT, test_scores_RF, test_scores_XGB, test_scores_ANN]

    fig, ax = plt.subplots(figsize=(15,8))
    sns.boxplot(data=test_rmse)
    plt.xticks(range(len(test_rmse)), names)
    plt.xlabel('Model')
    plt.title('Test RMSE')
    plt.ylabel('RMSE')
    plt.grid(alpha=0.6)
    plt.show()

    train_and_test_df = pd.merge(train_scores.groupby('Model name').mean(), test_scores.groupby('Model name').mean(), on = 'Model name', how = 'outer')
    print("RMSE and R2 Scores")
    print(train_and_test_df)

plot_regressors(X_with_ae, Y)
# Out:
# 17/17 [==============================] - 0s 243us/step
# 8/8 [==============================] - 0s 297us/step
# 22/22 [==============================] - 0s 232us/step
# 3/3 [==============================] - 0s 493us/step
# 22/22 [==============================] - 0s 227us/step
# 3/3 [==============================] - 0s 492us/step
# 22/22 [==============================] - 0s 236us/step
# 3/3 [==============================] - 0s 514us/step
# 22/22 [==============================] - 0s 266us/step
# 3/3 [==============================] - 0s 511us/step
# 22/22 [==============================] - 0s 213us/step
# 3/3 [==============================] - 0s 476us/step
# 22/22 [==============================] - 0s 220us/step
# 3/3 [==============================] - 0s 482us/step
# 22/22 [==============================] - 0s 211us/step
# 3/3 [==============================] - 0s 471us/step
# 22/22 [==============================] - 0s 213us/step
# 3/3 [==============================] - 0s 479us/step
# 22/22 [==============================] - 0s 209us/step
# 3/3 [==============================] - 0s 441us/step
# 22/22 [==============================] - 0s 219us/step
# 3/3 [==============================] - 0s 467us/step
# RMSE and R2 Scores
#                      Train RMSE  Train R2-Score  Test RMSE  Test R2-Score
# Model name
# ANN                8.886006e-02        0.184509   0.099935      -0.341819
# Decision Tree      2.907995e-10        1.000000   0.132130      -0.115137
# Linear Regression  1.172376e-01       -1.114458   0.121404      -1.940863
# Random Forest      4.064144e-02        0.885897   0.101061      -0.021960
# XGBoost            1.079393e-03        0.999942   0.113025      -0.064759

# %%
# Define input layer
input_layer = Input(shape=(X_train.shape[1],))
latent_feature = 4

# Encoder layers
encoder_layer1 = Dense(64, activation='relu')(input_layer)
encoder_layer2 = Dense(32, activation='relu')(encoder_layer1)
encoder_output = Dense(latent_feature, activation='relu')(encoder_layer2)  # Latent view

# Decoder layers
decoder_layer1 = Dense(32, activation='relu')(encoder_output)
decoder_layer2 = Dense(64, activation='relu')(decoder_layer1)
decoder_output = Dense(X_train.shape[1], activation='sigmoid')(decoder_layer2)

# Compile the autoencoder
autoencoder = Model(inputs=input_layer, outputs=decoder_output)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

autoencoder.fit(X_train, X_train, epochs=100, batch_size=32, validation_data=(X_test, X_test), verbose=0)

encoder = Model(inputs=input_layer, outputs=encoder_output)
encoded_data = encoder.predict(X_train)
encoded_data_test = encoder.predict(X_test)

combined_encoded_data = np.concatenate([encoded_data, encoded_data_test], axis=0)
X_with_ae = np.concatenate([normalised_df_regression, combined_encoded_data], axis=1)
X_with_ae.shape

def plot_regressors(X, y):
    
    models = [
        LinearRegression(),
        DecisionTreeRegressor(random_state=0),
        RandomForestRegressor(random_state=0),
        XGBRegressor(random_state=0)
    ]
    
    # Define ANN model
    def build_ann():
        model = Sequential()
        model.add(Dense(units=16, activation='relu', input_shape=(X.shape[1],)))
        model.add(Dense(units=8, activation='relu'))
        model.add(Dense(units=1))
        model.compile(optimizer='adam', loss='mean_squared_error')
        return model
    
    models.append(build_ann())
    
    names = ["Linear Regression", "Decision Tree", "Random Forest", "XGBoost", "ANN"]

    entries_train = []
    entries_test = []

    kf = KFold(n_splits=10, shuffle=False)

    for train_index, test_index in kf.split(X):
        
        X_train_fold, X_test_fold = X[train_index], X[test_index]
        y_train_fold, y_test_fold = y[train_index], y[test_index]

        for idx, model in enumerate(models):
            model_name = names[idx]

            # Train the ANN model
            if model_name == "ANN":
                model.fit(X_train_fold, y_train_fold, epochs=50, verbose=0, batch_size=32)
            else:
                model.fit(X_train_fold, y_train_fold)
                
            y_train_pred_fold = model.predict(X_train_fold)

            # RMSE and R2 score on training set
            train_rmse = np.sqrt(mean_squared_error(y_train_pred_fold, y_train_fold))
            r2_train = r2_score(y_train_pred_fold, y_train_fold)
            entries_train.append((model_name, train_rmse, r2_train))
            train_scores = pd.DataFrame(entries_train, columns=["Model name", "Train RMSE", "Train R2-Score"])
            
            y_test_pred_fold = model.predict(X_test_fold)

            # RMSE and R2 score on the test set
            test_rmse = np.sqrt(mean_squared_error(y_test_pred_fold, y_test_fold))
            r2_test = r2_score(y_test_pred_fold, y_test_fold)
            entries_test.append((model_name, test_rmse, r2_test))
            test_scores = pd.DataFrame(entries_test, columns=["Model name", "Test RMSE", "Test R2-Score"])

    # Getting the test RMSE values for each model
    test_scores_LR = test_scores[test_scores['Model name'] == 'Linear Regression']['Test RMSE'].values.tolist()
    test_scores_DT = test_scores[test_scores['Model name'] == 'Decision Tree']['Test RMSE'].values.tolist()
    test_scores_RF = test_scores[test_scores['Model name'] == 'Random Forest']['Test RMSE'].values.tolist()
    test_scores_XGB = test_scores[test_scores['Model name'] == 'XGBoost']['Test RMSE'].values.tolist()
    test_scores_ANN = test_scores[test_scores['Model name'] == 'ANN']['Test RMSE'].values.tolist()
    test_rmse = [test_scores_LR, test_scores_DT, test_scores_RF, test_scores_XGB, test_scores_ANN]

    fig, ax = plt.subplots(figsize=(15,8))
    sns.boxplot(data=test_rmse)
    plt.xticks(range(len(test_rmse)), names)
    plt.xlabel('Model')
    plt.title('Test RMSE')
    plt.ylabel('RMSE')
    plt.grid(alpha=0.6)
    plt.show()

    train_and_test_df = pd.merge(train_scores.groupby('Model name').mean(), test_scores.groupby('Model name').mean(), on = 'Model name', how = 'outer')
    print("RMSE and R2 Scores")
    print(train_and_test_df)

plot_regressors(X_with_ae, Y)
# Out:
# 17/17 [==============================] - 0s 250us/step
# 8/8 [==============================] - 0s 286us/step
# 22/22 [==============================] - 0s 234us/step
# 3/3 [==============================] - 0s 467us/step
# 22/22 [==============================] - 0s 233us/step
# 3/3 [==============================] - 0s 497us/step
# 22/22 [==============================] - 0s 231us/step
# 3/3 [==============================] - 0s 482us/step
# 22/22 [==============================] - 0s 229us/step
# 3/3 [==============================] - 0s 462us/step
# 22/22 [==============================] - 0s 215us/step
# 3/3 [==============================] - 0s 476us/step
# 22/22 [==============================] - 0s 204us/step
# 3/3 [==============================] - 0s 466us/step
# 22/22 [==============================] - 0s 211us/step
# 3/3 [==============================] - 0s 490us/step
# 22/22 [==============================] - 0s 213us/step
# 3/3 [==============================] - 0s 451us/step
# 22/22 [==============================] - 0s 216us/step
# 3/3 [==============================] - 0s 502us/step
# 22/22 [==============================] - 0s 218us/step
# 3/3 [==============================] - 0s 491us/step
# RMSE and R2 Scores
#                      Train RMSE  Train R2-Score  Test RMSE  Test R2-Score
# Model name
# ANN                9.341432e-02        0.108168   0.097357      -0.502574
# Decision Tree      2.907995e-10        1.000000   0.134105      -0.201199
# Linear Regression  1.170482e-01       -1.093349   0.121707      -1.889554
# Random Forest      4.068399e-02        0.884202   0.102956      -0.082648
# XGBoost            1.057936e-03        0.999944   0.114267      -0.131101

# %%
# Define input layer
input_layer = Input(shape=(X_train.shape[1],))
latent_feature =
/step
# RMSE and R2 Scores
#                      Train RMSE  Train R2-Score  Test RMSE  Test R2-Score
# Model name
# ANN                1.017540e-01       -1.398918   0.104289      -4.548740
# Decision Tree      2.907995e-10        1.000000   0.134571      -0.154672
# Linear Regression  1.168859e-01       -1.074841   0.121904      -1.951408
# Random Forest      4.091682e-02        0.884435   0.101824      -0.070009
# XGBoost            9.155781e-04        0.999958   0.110199      -0.227205

# %%
# Define input layer
input_layer = Input(shape=(X_train.shape[1],))
latent_feature = 15

# Encoder layers
encoder_layer1 = Dense(64, activation='relu')(input_layer)
encoder_layer2 = Dense(32, activation='relu')(encoder_layer1)
encoder_output = Dense(latent_feature, activation='relu')(encoder_layer2)  # Latent view

# Decoder layers
decoder_layer1 = Dense(32, activation='relu')(encoder_output)
decoder_layer2 = Dense(64, activation='relu')(decoder_layer1)
decoder_output = Dense(X_train.shape[1], activation='sigmoid')(decoder_layer2)

# Compile the autoencoder
autoencoder = Model(inputs=input_layer, outputs=decoder_output)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

autoencoder.fit(X_train, X_train, epochs=100, batch_size=32, validation_data=(X_test, X_test), verbose=0)

encoder = Model(inputs=input_layer, outputs=encoder_output)
encoded_data = encoder.predict(X_train)
encoded_data_test = encoder.predict(X_test)

combined_encoded_data = np.concatenate([encoded_data, encoded_data_test], axis=0)
X_with_ae = np.concatenate([normalised_df_regression, combined_encoded_data], axis=1)
X_with_ae.shape

def plot_regressors(X, y):
    
    models = [
        LinearRegression(),
        DecisionTreeRegressor(random_state=0),
        RandomForestRegressor(random_state=0),
        XGBRegressor(random_state=0)
    ]
    
    # Define ANN model
    def build_ann():
        model = Sequential()
        model.add(Dense(units=16, activation='relu', input_shape=(X.shape[1],)))
        model.add(Dense(units=8, activation='relu'))
        model.add(Dense(units=1))
        model.compile(optimizer='adam', loss='mean_squared_error')
        return model
    
    models.append(build_ann())
    
    names = ["Linear Regression", "Decision Tree", "Random Forest", "XGBoost", "ANN"]

    entries_train = []
    entries_test = []

    kf = KFold(n_splits=10, shuffle=False)

    for train_index, test_index in kf.split(X):
        
        X_train_fold, X_test_fold = X[train_index], X[test_index]
        y_train_fold, y_test_fold = y[train_index], y[test_index]

        for idx, model in enumerate(models):
            model_name = names[idx]

            # Train the ANN model
            if model_name == "ANN":
                model.fit(X_train_fold, y_train_fold, epochs=50, verbose=0, batch_size=32)
            else:
                model.fit(X_train_fold, y_train_fold)
                
            y_train_pred_fold = model.predict(X_train_fold)

            # RMSE and R2 score on training set
            train_rmse = np.sqrt(mean_squared_error(y_train_pred_fold, y_train_fold))
            r2_train = r2_score(y_train_pred_fold, y_train_fold)
            entries_train.append((model_name, train_rmse, r2_train))
            train_scores = pd.DataFrame(entries_train, columns=["Model name", "Train RMSE", "Train R2-Score"])
            
            y_test_pred_fold = model.predict(X_test_fold)

            # RMSE and R2 score on the test set
            test_rmse = np.sqrt(mean_squared_error(y_test_pred_fold, y_test_fold))
            r2_test = r2_score(y_test_pred_fold, y_test_fold)
            entries_test.append((model_name, test_rmse, r2_test))
            test_scores = pd.DataFrame(entries_test, columns=["Model name", "Test RMSE", "Test R2-Score"])

    # Getting the test RMSE values for each model
    test_scores_LR = test_scores[test_scores['Model name'] == 'Linear Regression']['Test RMSE'].values.tolist()
    test_scores_DT = test_scores[test_scores['Model name'] == 'Decision Tree']['Test RMSE'].values.tolist()
    test_scores_RF = test_scores[test_scores['Model name'] == 'Random Forest']['Test RMSE'].values.tolist()
    test_scores_XGB = test_scores[test_scores['Model name'] == 'XGBoost']['Test RMSE'].values.tolist()
    test_scores_ANN = test_scores[test_scores['Model name'] == 'ANN']['Test RMSE'].values.tolist()
    test_rmse = [test_scores_LR, test_scores_DT, test_scores_RF, test_scores_XGB, test_scores_ANN]

    fig, ax = plt.subplots(figsize=(15,8))
    sns.boxplot(data=test_rmse)
    plt.xticks(range(len(test_rmse)), names)
    plt.xlabel('Model')
    plt.title('Test RMSE')
    plt.ylabel('RMSE')
    plt.grid(alpha=0.6)
    plt.show()

    train_and_test_df = pd.merge(train_scores.groupby('Model name').mean(), test_scores.groupby('Model name').mean(), on = 'Model name', how = 'outer')
    print("RMSE and R2 Scores")
    print(train_and_test_df)

plot_regressors(X_with_ae, Y)
# Out:
# 17/17 [==============================] - 0s 248us/step
# 8/8 [==============================] - 0s 310us/step
# 22/22 [==============================] - 0s 239us/step
# 3/3 [==============================] - 0s 494us/step
# 22/22 [==============================] - 0s 242us/step
# 3/3 [==============================] - 0s 464us/step
# 22/22 [==============================] - 0s 222us/step
# 3/3 [==============================] - 0s 562us/step
# 22/22 [==============================] - 0s 232us/step
# 3/3 [==============================] - 0s 486us/step
# 22/22 [==============================] - 0s 217us/step
# 3/3 [==============================] - 0s 420us/step
# 22/22 [==============================] - 0s 219us/step
# 3/3 [==============================] - 0s 475us/step
# 22/22 [==============================] - 0s 219us/step
# 3/3 [==============================] - 0s 476us/step
# 22/22 [==============================] - 0s 217us/step
# 3/3 [==============================] - 0s 465us/step
# 22/22 [==============================] - 0s 216us/step
# 3/3 [==============================] - 0s 497us/step
# 22/22 [==============================] - 0s 214us/step
# 3/3 [==============================] - 0s 490us/step
# RMSE and R2 Scores
#                      Train RMSE  Train R2-Score  Test RMSE  Test R2-Score
# Model name
# ANN                9.017203e-02        0.162247   0.095848      -0.410420
# Decision Tree      2.492481e-10        1.000000   0.129579      -0.394485
# Linear Regression  1.159832e-01       -0.978997   0.121377      -1.693902
# Random Forest      4.074795e-02        0.884123   0.101202      -0.037602
# XGBoost            8.405641e-04        0.999965   0.112391      -0.336004

# %%
# Define input layer
input_layer = Input(shape=(X_train.shape[1],))
latent_feature = 1

# Encoder layers
encoder_layer1 = Dense(64, activation='relu')(input_layer)
encoder_layer2 = Dense(32, activation='relu')(encoder_layer1)
encoder_layer3 = Dense(32, activation='relu')(encoder_layer2)
encoder_layer4 = Dense(32, activation='relu')(encoder_layer3)
encoder_layer5 = Dense(32, activation='relu')(encoder_layer4)
encoder_output = Dense(latent_feature, activation='relu')(encoder_layer5)  # Latent view

# Decoder layers
decoder_layer1 = Dense(32, activation='relu')(encoder_output)
decoder_layer2 = Dense(64, activation='relu')(decoder_layer1)
decoder_layer3 = Dense(64, activation='relu')(decoder_layer2)
decoder_layer4 = Dense(64, activation='relu')(decoder_layer3)
decoder_layer5 = Dense(64, activation='relu')(decoder_layer4)
decoder_output = Dense(X_train.shape[1], activation='sigmoid')(decoder_layer5)

# Compile the autoencoder
autoencoder = Model(inputs=input_layer, outputs=decoder_output)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

autoencoder.fit(X_train, X_train, epochs=100, batch_size=32, validation_data=(X_test, X_test), verbose=0)

encoder = Model(inputs=input_layer, outputs=encoder_output)
encoded_data = encoder.predict(X_train)
encoded_data_test = encoder.predict(X_test)

combined_encoded_data = np.concatenate([encoded_data, encoded_data_test], axis=0)
X_with_ae = np.concatenate([normalised_df_regression, combined_encoded_data], axis=1)
X_with_ae.shape

def plot_regressors(X, y):
    
    models = [
        LinearRegression(),
        DecisionTreeRegressor(random_state=0),
        RandomForestRegressor(random_state=0),
        XGBRegressor(random_state=0)
    ]
    
    # Define ANN model
    def build_ann():
        model = Sequential()
        model.add(Dense(units=16, activation='relu', input_shape=(X.shape[1],)))
        model.add(Dense(units=8, activation='relu'))
        model.add(Dense(units=1))
        model.compile(optimizer='adam', loss='mean_squared_error')
        return model
    
    models.append(build_ann())
    
    names = ["Linear Regression", "Decision Tree", "Random Forest", "XGBoost", "ANN"]

    entries_train = []
    entries_test = []

    kf = KFold(n_splits=10, shuffle=False)

    for train_index, test_index in kf.split(X):
        
        X_train_fold, X_test_fold = X[train_index], X[test_index]
        y_train_fold, y_test_fold = y[train_index], y[test_index]

        for idx, model in enumerate(models):
            model_name = names[idx]

            # Train the ANN model
            if model_name == "ANN":
                model.fit(X_train_fold, y_train_fold, epochs=50, verbose=0, batch_size=32)
            else:
                model.fit(X_train_fold, y_train_fold)
                
            y_train_pred_fold = model.predict(X_train_fold)

            # RMSE and R2 score on training set
            train_rmse = np.sqrt(mean_squared_error(y_train_pred_fold, y_train_fold))
            r2_train = r2_score(y_train_pred_fold, y_train_fold)
            entries_train.append((model_name, train_rmse, r2_train))
            train_scores = pd.DataFrame(entries_train, columns=["Model name", "Train RMSE", "Train R2-Score"])
            
            y_test_pred_fold = model.predict(X_test_fold)

            # RMSE and R2 score on the test set
            test_rmse = np.sqrt(mean_squared_error(y_test_pred_fold, y_test_fold))
            r2_test = r2_score(y_test_pred_fold, y_test_fold)
            entries_test.append((model_name, test_rmse, r2_test))
            test_scores = pd.DataFrame(entries_test, columns=["Model name", "Test RMSE", "Test R2-Score"])

    # Getting the test RMSE values for each model
    test_scores_LR = test_scores[test_scores['Model name'] == 'Linear Regression']['Test RMSE'].values.tolist()
    test_scores_DT = test_scores[test_scores['Model name'] == 'Decision Tree']['Test RMSE'].values.tolist()
    test_scores_RF = test_scores[test_scores['Model name'] == 'Random Forest']['Test RMSE'].values.tolist()
    test_scores_XGB = test_scores[test_scores['Model name'] == 'XGBoost']['Test RMSE'].values.tolist()
    test_scores_ANN = test_scores[test_scores['Model name'] == 'ANN']['Test RMSE'].values.tolist()
    test_rmse = [test_scores_LR, test_scores_DT, test_scores_RF, test_scores_XGB, test_scores_ANN]

    fig, ax = plt.subplots(figsize=(15,8))
    sns.boxplot(data=test_rmse)
    plt.xticks(range(len(test_rmse)), names)
    plt.xlabel('Model')
    plt.title('Test RMSE')
    plt.ylabel('RMSE')
    plt.grid(alpha=0.6)
    plt.show()

    train_and_test_df = pd.merge(train_scores.groupby('Model name').mean(), test_scores.groupby('Model name').mean(), on = 'Model name', how = 'outer')
    print("RMSE and R2 Scores")
    print(train_and_test_df)

plot_regressors(X_with_ae, Y)
# Out:
# 17/17 [==============================] - 0s 276us/step
# 8/8 [==============================] - 0s 300us/step
# 22/22 [==============================] - 0s 236us/step
# 3/3 [==============================] - 0s 483us/step
# 22/22 [==============================] - 0s 252us/step
# 3/3 [==============================] - 0s 543us/step
# 22/22 [==============================] - 0s 233us/step
# 3/3 [==============================] - 0s 491us/step
# 22/22 [==============================] - 0s 227us/step
# 3/3 [==============================] - 0s 469us/step
# 22/22 [==============================] - 0s 215us/step
# 3/3 [==============================] - 0s 478us/step
# 22/22 [==============================] - 0s 221us/step
# 3/3 [==============================] - 0s 437us/step
# 22/22 [==============================] - 0s 221us/step
# 3/3 [==============================] - 0s 470us/step
# 22/22 [==============================] - 0s 234us/step
# 3/3 [==============================] - 0s 486us/step
# 22/22 [==============================] - 0s 220us/step
# 3/3 [==============================] - 0s 447us/step
# 22/22 [==============================] - 0s 215us/step
# 3/3 [==============================] - 0s 472us/step
# RMSE and R2 Scores
#                      Train RMSE  Train R2-Score  Test RMSE  Test R2-Score
# Model name
# ANN                9.112721e-02        0.219278   0.101062      -0.528652
# Decision Tree      2.907995e-10        1.000000   0.151357      -0.552733
# Linear Regression  1.146560e-01       -0.849123   0.122206      -1.951308
# Random Forest      4.039877e-02        0.886746   0.102253      -0.153803
# XGBoost            1.239694e-03        0.999923   0.115229      -0.333004
