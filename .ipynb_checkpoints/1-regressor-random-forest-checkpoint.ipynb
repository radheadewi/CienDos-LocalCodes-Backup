# %%
import pandas as pd
pd.options.display.max_columns = None
pd.set_option('display.max_rows', 20)
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold

# %%
df_regression = pd.read_excel("feature-eng-data/regression_dataset.xlsx")
df_regression = df_regression.drop(df_regression.columns[0], axis=1)
df_regression = df_regression.drop("CalculationType", axis=1)
df_regression = df_regression.drop("S1S2TesCO2eEst", axis=1)
df_regression = df_regression.set_index("CompanyNumber")
df_regression['SIC'] = df_regression['SIC'].astype('category')
df_regression['root_parent'] = df_regression['root_parent'].astype('category')
df_regression['parent_2'] = df_regression['parent_2'].astype('category')

# %%
categorical_features = df_regression[["SIC", "root_parent", "parent_2"]]

# Drop the categorcial features
df_regression.drop(["SIC", "root_parent", "parent_2"], axis=1, inplace=True)

# %%
categorical_features_copy = categorical_features.copy()

# Convert the "root_parent" column to numeric type using cat.codes
categorical_features_copy["root_parent"] = categorical_features_copy["root_parent"].cat.codes

print(categorical_features_copy)
# Out:
#                  SIC  root_parent parent_2
# CompanyNumber
# 00019457         329            2     32.0
# 00024869        6512           10     65.0
# 00029559         701           12     70.0
# 00030226        1712            2     17.0
# 00033774        2059            2     20.0
# ...              ...          ...      ...
# SC334329       64202           10     64.0
# SC367563        8299           13     82.0
# SC419949       64921           10     64.0
# SC440783        1011            2     10.0
# SC578050       46431            6     46.0
#
# [765 rows x 3 columns]

# %%
df_regression
# Out:
#                AssetsM     TurnoverM      FTE  IR_CO2ePerAssetsM  \
# CompanyNumber
# 00019457        3152.0    603.300000   3152.0           0.060444
# 00024869        1048.0    486.000000   1048.0           0.253968
# 00029559       76060.0    291.200000  76060.0         516.260563
# 00030226         584.0    104.600000    584.0         473.260870
# 00033774        4017.0  15700.000000   4017.0        1866.017132
# ...                ...           ...      ...                ...
# SC334329         381.0     37.473996    381.0          61.967019
# SC367563        1125.0    108.500000   1125.0           5.116468
# SC419949           0.0     29.375452      0.0          20.503251
# SC440783        1330.0    498.237572   1330.0        9889.035686
# SC578050           0.0     99.051884      0.0          16.295030
#
#                IR_CO2ePerTurnoverM  IR_CO2ePerFTE  DefraRatio  \
# CompanyNumber
# 00019457                  0.078988       0.015111      1.3750
# 00024869                  0.954733       0.442748      0.0375
# 00029559                755.762887       2.891494      0.3750
# 00030226                373.200000      67.099315      6.6250
# 00033774                319.124586    1247.263132      3.8750
# ...                            ...            ...         ...
# SC334329                 33.135135       3.217848      0.0375
# SC367563                 25.995413       2.518667      0.3750
# SC419949                 28.137931       0.000000      0.0375
# SC440783                 25.656627       9.606767      2.6250
# SC578050                  1.242424       0.000000      1.2500
#
#                NormalisedIrCO2ePerAssetsM  NormalisedIrCO2ePerTurnoverM  \
# CompanyNumber
# 00019457                        88.414665                        39.608
# 00024869                        88.414665                        39.608
# 00029559                        88.414665                        39.608
# 00030226                        88.414665                        39.608
# 00033774                        88.414665                        39.608
# ...                                   ...                           ...
# SC334329                        88.414665                        39.608
# SC367563                        88.414665                        39.608
# SC419949                        88.414665                        39.608
# SC440783                        88.414665                        39.608
# SC578050                        88.414665                        39.608
#
#                NormalisedIrCO2ePerFTE  ScoreC1a  ScoreC1t  ScoreC1f  ScoreC2  \
# CompanyNumber
# 00019457                     7.726939        10      10.0  9.000000      9.0
# 00024869                     7.726939        10       9.0  8.000000      6.0
# 00029559                     7.726939         2       1.0  5.000000      2.0
# 00030226                     7.726939         2       2.0  2.000000      5.0
# 00033774                     7.726939         1       2.0  1.000000      2.0
# ...                               ...       ...       ...       ...      ...
# SC334329                     7.726939         5       5.0  5.000000      2.0
# SC367563                     7.726939         8       5.0  5.000000      6.0
# SC419949                     7.726939         7       5.0  5.195021      2.0
# SC440783                     7.726939         1       5.0  3.000000      5.0
# SC578050                     7.726939         7       9.0  5.195021      9.0
#
#                ScoreC1  MeanTotalGHG        MeanCO2  MeanCH4      MeanN2O  \
# CompanyNumber
# 00019457           9.0      122937.8  110754.621875    319.9  5781.643750
# 00024869           9.0         305.1     268.003125      1.0     0.946875
# 00029559           2.0        2288.1    2144.109375      9.1    10.868750
# 00030226           2.0      122937.8  110754.621875    319.9  5781.643750
# 00033774           1.0      122937.8  110754.621875    319.9  5781.643750
# ...                ...           ...            ...      ...          ...
# SC334329           5.0         305.1     268.003125      1.0     0.946875
# SC367563           6.0        3310.9    3179.271875     10.5    20.143750
# SC419949           6.0         305.1     268.003125      1.0     0.946875
# SC440783           3.0      122937.8  110754.621875    319.9  5781.643750
# SC578050           8.0       15214.9   12694.615625     46.3    97.940625
#
#                    MeanHFC    MeanPFC  MeanNF3     MeanSF6  GHGIntensity  \
# CompanyNumber
# 00019457       5166.559375  410.50625      0.3  504.234375      0.814688
# 00024869         35.025000    0.08125      0.0    0.000000      0.000000
# 00029559        100.643750    0.11875      0.0   23.209375      0.022500
# 00030226       5166.559375  410.50625      0.3  504.234375      0.814688
# 00033774       5166.559375  410.50625      0.3  504.234375      0.814688
# ...                    ...        ...      ...         ...           ...
# SC334329         35.025000    0.08125      0.0    0.000000      0.000000
# SC367563        100.806250    0.14375      0.0    0.000000      0.049375
# SC419949         35.025000    0.08125      0.0    0.000000      0.000000
# SC440783       5166.559375  410.50625      0.3  504.234375      0.814688
# SC578050       2376.128125    0.00000      0.0    0.000000      0.083125
#
#                CO2Intensity       PM10       PM25          CO       NMVOC  \
# CompanyNumber
# 00019457           0.724688  42.680938  32.870906  632.933031  409.348156
# 00024869           0.000000   0.032344   0.027031    2.050844    0.366812
# 00029559           0.020938   0.372188   0.322406   22.857313    4.384531
# 00030226           0.724688  42.680938  32.870906  632.933031  409.348156
# 00033774           0.724688  42.680938  32.870906  632.933031  409.348156
# ...                     ...        ...        ...         ...         ...
# SC334329           0.000000   0.032344   0.027031    2.050844    0.366812
# SC367563           0.047813   1.115719   0.997531   50.637906    8.058969
# SC419949           0.000000   0.032344   0.027031    2.050844    0.366812
# SC440783           0.724688  42.680938  32.870906  632.933031  409.348156
# SC578050           0.070313   4.089688   3.473219  106.895281   86.132250
#
#                 Benzene  Butadine  EnergyIntensity  Electricity  \
# CompanyNumber
# 00019457       3.675875     0.593              2.6         1.81
# 00024869       0.015906     0.003              6.2         0.78
# 00029559       0.180562     0.039              1.6         0.88
# 00030226       3.675875     0.593              2.6         1.81
# 00033774       3.675875     0.593              2.6         1.81
# ...                 ...       ...              ...          ...
# SC334329       0.015906     0.003              6.2         0.78
# SC367563       0.377531     0.090              2.6         1.44
# SC419949       0.015906     0.003              6.2         0.78
# SC440783       3.675875     0.593              2.6         1.81
# SC578050       0.889250     0.241              3.7         2.48
#
#                Petrol/diesel  Natural gas  OtherEenergy  EnergyTotal  \
# CompanyNumber
# 00019457                0.69         0.83          9.38        12.70
# 00024869                0.17         0.07          0.01         1.03
# 00029559                1.12         0.17          0.08         2.25
# 00030226                0.69         0.83          9.38        12.70
# 00033774                0.69         0.83          9.38        12.70
# ...                      ...          ...           ...          ...
# SC334329                0.17         0.07          0.01         1.03
# SC367563                3.47         0.42          0.35         5.69
# SC419949                0.17         0.07          0.01         1.03
# SC440783                0.69         0.83          9.38        12.70
# SC578050                3.52         1.90          1.90         9.74
#
#                MeanTotalGHG_lv2  MeanCO2_lv2   S1S2CO2e
# CompanyNumber
# 00019457               0.160938     0.159688      47.63
# 00024869               0.000000     0.000000     269.00
# 00029559               0.044375     0.041875  219927.00
# 00030226               1.729687     1.721250   39186.00
# 00033774               3.748490     2.203646  431311.00
# ...                         ...          ...        ...
# SC334329               0.000000     0.000000       0.00
# SC367563               0.036563     0.034375    2272.20
# SC419949               0.000000     0.000000     771.00
# SC440783               0.518398     0.505039   12715.00
# SC578050               0.110312     0.099687     123.00
#
# [765 rows x 40 columns]

# %%
df_concatenated = pd.concat([categorical_features_copy, df_regression], axis=1)
df_concatenated
# Out:
#                  SIC  root_parent parent_2  AssetsM     TurnoverM      FTE  \
# CompanyNumber
# 00019457         329            2     32.0   3152.0    603.300000   3152.0
# 00024869        6512           10     65.0   1048.0    486.000000   1048.0
# 00029559         701           12     70.0  76060.0    291.200000  76060.0
# 00030226        1712            2     17.0    584.0    104.600000    584.0
# 00033774        2059            2     20.0   4017.0  15700.000000   4017.0
# ...              ...          ...      ...      ...           ...      ...
# SC334329       64202           10     64.0    381.0     37.473996    381.0
# SC367563        8299           13     82.0   1125.0    108.500000   1125.0
# SC419949       64921           10     64.0      0.0     29.375452      0.0
# SC440783        1011            2     10.0   1330.0    498.237572   1330.0
# SC578050       46431            6     46.0      0.0     99.051884      0.0
#
#                IR_CO2ePerAssetsM  IR_CO2ePerTurnoverM  IR_CO2ePerFTE  \
# CompanyNumber
# 00019457                0.060444             0.078988       0.015111
# 00024869                0.253968             0.954733       0.442748
# 00029559              516.260563           755.762887       2.891494
# 00030226              473.260870           373.200000      67.099315
# 00033774             1866.017132           319.124586    1247.263132
# ...                          ...                  ...            ...
# SC334329               61.967019            33.135135       3.217848
# SC367563                5.116468            25.995413       2.518667
# SC419949               20.503251            28.137931       0.000000
# SC440783             9889.035686            25.656627       9.606767
# SC578050               16.295030             1.242424       0.000000
#
#                DefraRatio  NormalisedIrCO2ePerAssetsM  \
# CompanyNumber
# 00019457           1.3750                   88.414665
# 00024869           0.0375                   88.414665
# 00029559           0.3750                   88.414665
# 00030226           6.6250                   88.414665
# 00033774           3.8750                   88.414665
# ...                   ...                         ...
# SC334329           0.0375                   88.414665
# SC367563           0.3750                   88.414665
# SC419949           0.0375                   88.414665
# SC440783           2.6250                   88.414665
# SC578050           1.2500                   88.414665
#
#                NormalisedIrCO2ePerTurnoverM  NormalisedIrCO2ePerFTE  ScoreC1a  \
# CompanyNumber
# 00019457                             39.608                7.726939        10
# 00024869                             39.608                7.726939        10
# 00029559                             39.608                7.726939         2
# 00030226                             39.608                7.726939         2
# 00033774                             39.608                7.726939         1
# ...                                     ...                     ...       ...
# SC334329                             39.608                7.726939         5
# SC367563                             39.608                7.726939         8
# SC419949                             39.608                7.726939         7
# SC440783                             39.608                7.726939         1
# SC578050                             39.608                7.726939         7
#
#                ScoreC1t  ScoreC1f  ScoreC2  ScoreC1  MeanTotalGHG  \
# CompanyNumber
# 00019457           10.0  9.000000      9.0      9.0      122937.8
# 00024869            9.0  8.000000      6.0      9.0         305.1
# 00029559            1.0  5.000000      2.0      2.0        2288.1
# 00030226            2.0  2.000000      5.0      2.0      122937.8
# 00033774            2.0  1.000000      2.0      1.0      122937.8
# ...                 ...       ...      ...      ...           ...
# SC334329            5.0  5.000000      2.0      5.0         305.1
# SC367563            5.0  5.000000      6.0      6.0        3310.9
# SC419949            5.0  5.195021      2.0      6.0         305.1
# SC440783            5.0  3.000000      5.0      3.0      122937.8
# SC578050            9.0  5.195021      9.0      8.0       15214.9
#
#                      MeanCO2  MeanCH4      MeanN2O      MeanHFC    MeanPFC  \
# CompanyNumber
# 00019457       110754.621875    319.9  5781.643750  5166.559375  410.50625
# 00024869          268.003125      1.0     0.946875    35.025000    0.08125
# 00029559         2144.109375      9.1    10.868750   100.643750    0.11875
# 00030226       110754.621875    319.9  5781.643750  5166.559375  410.50625
# 00033774       110754.621875    319.9  5781.643750  5166.559375  410.50625
# ...                      ...      ...          ...          ...        ...
# SC334329          268.003125      1.0     0.946875    35.025000    0.08125
# SC367563         3179.271875     10.5    20.143750   100.806250    0.14375
# SC419949          268.003125      1.0     0.946875    35.025000    0.08125
# SC440783       110754.621875    319.9  5781.643750  5166.559375  410.50625
# SC578050        12694.615625     46.3    97.940625  2376.128125    0.00000
#
#                MeanNF3     MeanSF6  GHGIntensity  CO2Intensity       PM10  \
# CompanyNumber
# 00019457           0.3  504.234375      0.814688      0.724688  42.680938
# 00024869           0.0    0.000000      0.000000      0.000000   0.032344
# 00029559           0.0   23.209375      0.022500      0.020938   0.372188
# 00030226           0.3  504.234375      0.814688      0.724688  42.680938
# 00033774           0.3  504.234375      0.814688      0.724688  42.680938
# ...                ...         ...           ...           ...        ...
# SC334329           0.0    0.000000      0.000000      0.000000   0.032344
# SC367563           0.0    0.000000      0.049375      0.047813   1.115719
# SC419949           0.0    0.000000      0.000000      0.000000   0.032344
# SC440783           0.3  504.234375      0.814688      0.724688  42.680938
# SC578050           0.0    0.000000      0.083125      0.070313   4.089688
#
#                     PM25          CO       NMVOC   Benzene  Butadine  \
# CompanyNumber
# 00019457       32.870906  632.933031  409.348156  3.675875     0.593
# 00024869        0.027031    2.050844    0.366812  0.015906     0.003
# 00029559        0.322406   22.857313    4.384531  0.180562     0.039
# 00030226       32.870906  632.933031  409.348156  3.675875     0.593
# 00033774       32.870906  632.933031  409.348156  3.675875     0.593
# ...                  ...         ...         ...       ...       ...
# SC334329        0.027031    2.050844    0.366812  0.015906     0.003
# SC367563        0.997531   50.637906    8.058969  0.377531     0.090
# SC419949        0.027031    2.050844    0.366812  0.015906     0.003
# SC440783       32.870906  632.933031  409.348156  3.675875     0.593
# SC578050        3.473219  106.895281   86.132250  0.889250     0.241
#
#                EnergyIntensity  Electricity  Petrol/diesel  Natural gas  \
# CompanyNumber
# 00019457                   2.6         1.81           0.69         0.83
# 00024869                   6.2         0.78           0.17         0.07
# 00029559                   1.6         0.88           1.12         0.17
# 00030226                   2.6         1.81           0.69         0.83
# 00033774                   2.6         1.81           0.69         0.83
# ...                        ...          ...            ...          ...
# SC334329                   6.2         0.78           0.17         0.07
# SC367563                   2.6         1.44           3.47         0.42
# SC419949                   6.2         0.78           0.17         0.07
# SC440783                   2.6         1.81           0.69         0.83
# SC578050                   3.7         2.48           3.52         1.90
#
#                OtherEenergy  EnergyTotal  MeanTotalGHG_lv2  MeanCO2_lv2  \
# CompanyNumber
# 00019457               9.38        12.70          0.160938     0.159688
# 00024869               0.01         1.03          0.000000     0.000000
# 00029559               0.08         2.25          0.044375     0.041875
# 00030226               9.38        12.70          1.729687     1.721250
# 00033774               9.38        12.70          3.748490     2.203646
# ...                     ...          ...               ...          ...
# SC334329               0.01         1.03          0.000000     0.000000
# SC367563               0.35         5.69          0.036563     0.034375
# SC419949               0.01         1.03          0.000000     0.000000
# SC440783               9.38        12.70          0.518398     0.505039
# SC578050               1.90         9.74          0.110312     0.099687
#
#                 S1S2CO2e
# CompanyNumber
# 00019457           47.63
# 00024869          269.00
# 00029559       219927.00
# 00030226        39186.00
# 00033774       431311.00
# ...                  ...
# SC334329            0.00
# SC367563         2272.20
# SC419949          771.00
# SC440783        12715.00
# SC578050          123.00
#
# [765 rows x 43 columns]

# %%
features_list = df_regression.columns

# %%
scaler = MinMaxScaler()
normalised_df_regression = scaler.fit_transform(df_regression)
S1S2CO2e = normalised_df_regression[:, -1]

# drop the label
normalised_df_regression = np.delete(normalised_df_regression, -1, axis=1)

# %%
normalised_df_regression.shape
# Out:
# (765, 39)

# %%
X = normalised_df_regression
Y = S1S2CO2e

X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.70, test_size=0.30, random_state=0)

print('Number of instances in X: {}'.format(np.shape(X)[0]))
print('Number of instances in X_train: {}'.format(X_train.shape[0]))
print('Number of instances in X_test: {}'.format(X_test.shape[0]))
print('Number of instances in X_train and X_test together: {}'.format(X_train.shape[0] + X_test.shape[0]))
# Out:
# Number of instances in X: 765
# Number of instances in X_train: 535
# Number of instances in X_test: 230
# Number of instances in X_train and X_test together: 765

# %%
rf_regressor = RandomForestRegressor()
rf_regressor.fit(X_train, y_train)
print('Training accuracy: {:.3f}'.format(rf_regressor.score(X_train, y_train)))

print('Testing accuracy by using score function: {:.3f}'.format(rf_regressor.score(X_test, y_test)))
print('Testing accuracy by using r2_score meric: {:.3f}'.format(r2_score(y_test, rf_regressor.predict(X_test))))
# Out:
# Training accuracy: 0.908
# Testing accuracy by using score function: 0.429
# Testing accuracy by using r2_score meric: 0.429

# %%
# perform 10-fold cross-validation
cv_scores = cross_val_score(rf_regressor, X_train, y_train, cv=10)

# print the cross-validation scores
print('Cross-validation scores: ', cv_scores)

# print the mean of the cross-validation scores
print('Mean cross-validation score: {:.3f}'.format(np.mean(cv_scores)))
# Out:
# Cross-validation scores:  [ 0.48106535  0.4746626   0.78924419  0.27405981  0.27607368  0.05525695
#  -0.07742124  0.4843325   0.27457946  0.18656287]
# Mean cross-validation score: 0.322

# %%
# make predictions on the test set
y_pred = rf_regressor.predict(X_test)

# calculate the RMSE
rmse = mean_squared_error(y_test, y_pred, squared=False)
print('Root Mean Squared Error: {:.3f}'.format(rmse))
# Out:
# Root Mean Squared Error: 0.129

# %%
# Define the number of folds for cross-validation
n_folds = 10

# Initialize an empty list to store RMSE scores for each fold
rmse_scores = []
r2_scores = []

# Create the KFold cross-validator
kfold = KFold(n_splits=n_folds, shuffle=False)

# Perform 10-fold cross-validation
for train_idx, test_idx in kfold.split(X):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = Y[train_idx], Y[test_idx]
    
    # Create and train the model
    rf_regressor.fit(X_train, y_train)
    
    # Evaluate the model on the test set and calculate RMSE
    y_pred = rf_regressor.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    rmse_scores.append(rmse)
    r2_scores.append(r2)

# Convert the RMSE scores to a NumPy array for easier calculations
rmse_scores = np.array(rmse_scores)
r2_scores = np.array(r2_scores)

# Calculate the mean and standard deviation of RMSE scores
mean_rmse = np.mean(rmse_scores)
std_rmse = np.std(rmse_scores)
mean_r2 = np.mean(r2_scores)
std_r2 = np.std(r2_scores)

print('10-Fold Cross-Validation RMSE Scores:')
print(rmse_scores)
print('Mean RMSE: {:.3f}'.format(mean_rmse))
print('Standard Deviation of RMSE: {:.3f}'.format(std_rmse))

print('10-Fold Cross-Validation R2 Scores:')
print(r2_scores)
print('Mean R2: {:.3f}'.format(mean_r2))
print('Standard Deviation of R2: {:.3f}'.format(std_r2))
# Out:
# 10-Fold Cross-Validation RMSE Scores:
# [0.16653053 0.09787687 0.13873344 0.13553932 0.14492719 0.09829728
#  0.03788929 0.07528046 0.06459419 0.04966944]
# Mean RMSE: 0.101
# Standard Deviation of RMSE: 0.042
# 10-Fold Cross-Validation R2 Scores:
# [ 0.1824733   0.48305901  0.1552625   0.26291007  0.50959051  0.40436981
#  -0.58074213  0.54356759  0.46902151  0.85280638]
# Mean R2: 0.328
# Standard Deviation of R2: 0.359

# %%
# summarise feature importance
for i,v in enumerate(rf_regressor.feature_importances_):
    print(f"Feature: {features_list[i]}, Score: {v}")

# plot feature importance
plt.bar([x for x in range(len(rf_regressor.feature_importances_))], rf_regressor.feature_importances_)

plt.show()
# Out:
# Feature: SIC, Score: 0.02161103538302685
# Feature: root_parent, Score: 0.00736262302115899
# Feature: parent_2, Score: 0.02015479109626455
# Feature: AssetsM, Score: 0.16163707996100893
# Feature: TurnoverM, Score: 0.22231566197815658
# Feature: FTE, Score: 0.1724164858162996
# Feature: IR_CO2ePerAssetsM, Score: 0.020021275889468927
# Feature: IR_CO2ePerTurnoverM, Score: 0.09345538394007168
# Feature: IR_CO2ePerFTE, Score: 0.05577100347301948
# Feature: DefraRatio, Score: 0.013753393537806236
# Feature: NormalisedIrCO2ePerAssetsM, Score: 0.0
# Feature: NormalisedIrCO2ePerTurnoverM, Score: 0.0
# Feature: NormalisedIrCO2ePerFTE, Score: 0.0
# Feature: ScoreC1a, Score: 0.007949603973442623
# Feature: ScoreC1t, Score: 0.009813501770996493
# Feature: ScoreC1f, Score: 0.03261669537690931
# Feature: ScoreC2, Score: 0.008829613155434332
# Feature: ScoreC1, Score: 0.027400717110675505
# Feature: S1S2TesCO2eEst, Score: 0.0070228603130911265
# Feature: MeanTotalGHG, Score: 0.0020757165342526127
# Feature: MeanCO2, Score: 0.0022487947686530654
# Feature: MeanCH4, Score: 0.003548860112417684
# Feature: MeanN2O, Score: 0.007846062262427117
# Feature: MeanHFC, Score: 0.014414114090728637
# Feature: MeanPFC, Score: 0.002330771208347105
# Feature: MeanNF3, Score: 0.00026827276748829087
# Feature: MeanSF6, Score: 0.005273362753948484
# Feature: GHGIntensity, Score: 0.003692152404251848
# Feature: CO2Intensity, Score: 0.004196209617012133
# Feature: PM10, Score: 0.0032915391955589926
# Feature: PM25, Score: 0.005458640251768609
# Feature: CO, Score: 0.0031792893515548053
# Feature: NMVOC, Score: 0.007199411130744005
# Feature: Benzene, Score: 0.004553656743911512
# Feature: Butadine, Score: 0.008279274879516935
# Feature: EnergyIntensity, Score: 0.0044449612532726735
# Feature: Electricity, Score: 0.0015385876810697515
# Feature: Petrol/diesel, Score: 0.0022787348510681263
# Feature: Natural gas, Score: 0.0013584023287536702
# Feature: OtherEenergy, Score: 0.004591599629855588
# Feature: EnergyTotal, Score: 0.0038136541999746433
# Feature: MeanTotalGHG_lv2, Score: 0.011810315176761623
# Feature: MeanCO2_lv2, Score: 0.01017589100983105

# %%
rf_regressor.n_features_in_
# Out:
# 42

# %% [markdown]
# Random Forests Regressor without level2 features (37 features)

# %%
df_regression.head()
# Out:
#                AssetsM  TurnoverM      FTE  IR_CO2ePerAssetsM  \
# CompanyNumber
# 00019457        3152.0      603.3   3152.0           0.060444
# 00024869        1048.0      486.0   1048.0           0.253968
# 00029559       76060.0      291.2  76060.0         516.260563
# 00030226         584.0      104.6    584.0         473.260870
# 00033774        4017.0    15700.0   4017.0        1866.017132
#
#                IR_CO2ePerTurnoverM  IR_CO2ePerFTE  DefraRatio  \
# CompanyNumber
# 00019457                  0.078988       0.015111      1.3750
# 00024869                  0.954733       0.442748      0.0375
# 00029559                755.762887       2.891494      0.3750
# 00030226                373.200000      67.099315      6.6250
# 00033774                319.124586    1247.263132      3.8750
#
#                NormalisedIrCO2ePerAssetsM  NormalisedIrCO2ePerTurnoverM  \
# CompanyNumber
# 00019457                        88.414665                        39.608
# 00024869                        88.414665                        39.608
# 00029559                        88.414665                        39.608
# 00030226                        88.414665                        39.608
# 00033774                        88.414665                        39.608
#
#                NormalisedIrCO2ePerFTE  ScoreC1a  ScoreC1t  ScoreC1f  ScoreC2  \
# CompanyNumber
# 00019457                     7.726939        10      10.0       9.0      9.0
# 00024869                     7.726939        10       9.0       8.0      6.0
# 00029559                     7.726939         2       1.0       5.0      2.0
# 00030226                     7.726939         2       2.0       2.0      5.0
# 00033774                     7.726939         1       2.0       1.0      2.0
#
#                ScoreC1  MeanTotalGHG        MeanCO2  MeanCH4      MeanN2O  \
# CompanyNumber
# 00019457           9.0      122937.8  110754.621875    319.9  5781.643750
# 00024869           9.0         305.1     268.003125      1.0     0.946875
# 00029559           2.0        2288.1    2144.109375      9.1    10.868750
# 00030226           2.0      122937.8  110754.621875    319.9  5781.643750
# 00033774           1.0      122937.8  110754.621875    319.9  5781.643750
#
#                    MeanHFC    MeanPFC  MeanNF3     MeanSF6  GHGIntensity  \
# CompanyNumber
# 00019457       5166.559375  410.50625      0.3  504.234375      0.814688
# 00024869         35.025000    0.08125      0.0    0.000000      0.000000
# 00029559        100.643750    0.11875      0.0   23.209375      0.022500
# 00030226       5166.559375  410.50625      0.3  504.234375      0.814688
# 00033774       5166.559375  410.50625      0.3  504.234375      0.814688
#
#                CO2Intensity       PM10       PM25          CO       NMVOC  \
# CompanyNumber
# 00019457           0.724688  42.680938  32.870906  632.933031  409.348156
# 00024869           0.000000   0.032344   0.027031    2.050844    0.366812
# 00029559           0.020938   0.372188   0.322406   22.857313    4.384531
# 00030226           0.724688  42.680938  32.870906  632.933031  409.348156
# 00033774           0.724688  42.680938  32.870906  632.933031  409.348156
#
#                 Benzene  Butadine  EnergyIntensity  Electricity  \
# CompanyNumber
# 00019457       3.675875     0.593              2.6         1.81
# 00024869       0.015906     0.003              6.2         0.78
# 00029559       0.180562     0.039              1.6         0.88
# 00030226       3.675875     0.593              2.6         1.81
# 00033774       3.675875     0.593              2.6         1.81
#
#                Petrol/diesel  Natural gas  OtherEenergy  EnergyTotal  \
# CompanyNumber
# 00019457                0.69         0.83          9.38        12.70
# 00024869                0.17         0.07          0.01         1.03
# 00029559                1.12         0.17          0.08         2.25
# 00030226                0.69         0.83          9.38        12.70
# 00033774                0.69         0.83          9.38        12.70
#
#                MeanTotalGHG_lv2  MeanCO2_lv2   S1S2CO2e
# CompanyNumber
# 00019457               0.160938     0.159688      47.63
# 00024869               0.000000     0.000000     269.00
# 00029559               0.044375     0.041875  219927.00
# 00030226               1.729687     1.721250   39186.00
# 00033774               3.748490     2.203646  431311.00

# %%
df_regression_2 = df_regression.drop(columns=["MeanCO2_lv2", "MeanTotalGHG_lv2"])

# %%
df_regression_2
# Out:
#                AssetsM     TurnoverM      FTE  IR_CO2ePerAssetsM  \
# CompanyNumber
# 00019457        3152.0    603.300000   3152.0           0.060444
# 00024869        1048.0    486.000000   1048.0           0.253968
# 00029559       76060.0    291.200000  76060.0         516.260563
# 00030226         584.0    104.600000    584.0         473.260870
# 00033774        4017.0  15700.000000   4017.0        1866.017132
# ...                ...           ...      ...                ...
# SC334329         381.0     37.473996    381.0          61.967019
# SC367563        1125.0    108.500000   1125.0           5.116468
# SC419949           0.0     29.375452      0.0          20.503251
# SC440783        1330.0    498.237572   1330.0        9889.035686
# SC578050           0.0     99.051884      0.0          16.295030
#
#                IR_CO2ePerTurnoverM  IR_CO2ePerFTE  DefraRatio  \
# CompanyNumber
# 00019457                  0.078988       0.015111      1.3750
# 00024869                  0.954733       0.442748      0.0375
# 00029559                755.762887       2.891494      0.3750
# 00030226                373.200000      67.099315      6.6250
# 00033774                319.124586    1247.263132      3.8750
# ...                            ...            ...         ...
# SC334329                 33.135135       3.217848      0.0375
# SC367563                 25.995413       2.518667      0.3750
# SC419949                 28.137931       0.000000      0.0375
# SC440783                 25.656627       9.606767      2.6250
# SC578050                  1.242424       0.000000      1.2500
#
#                NormalisedIrCO2ePerAssetsM  NormalisedIrCO2ePerTurnoverM  \
# CompanyNumber
# 00019457                        88.414665                        39.608
# 00024869                        88.414665                        39.608
# 00029559                        88.414665                        39.608
# 00030226                        88.414665                        39.608
# 00033774                        88.414665                        39.608
# ...                                   ...                           ...
# SC334329                        88.414665                        39.608
# SC367563                        88.414665                        39.608
# SC419949                        88.414665                        39.608
# SC440783                        88.414665                        39.608
# SC578050                        88.414665                        39.608
#
#                NormalisedIrCO2ePerFTE  ScoreC1a  ScoreC1t  ScoreC1f  ScoreC2  \
# CompanyNumber
# 00019457                     7.726939        10      10.0  9.000000      9.0
# 00024869                     7.726939        10       9.0  8.000000      6.0
# 00029559                     7.726939         2       1.0  5.000000      2.0
# 00030226                     7.726939         2       2.0  2.000000      5.0
# 00033774                     7.726939         1       2.0  1.000000      2.0
# ...                               ...       ...       ...       ...      ...
# SC334329                     7.726939         5       5.0  5.000000      2.0
# SC367563                     7.726939         8       5.0  5.000000      6.0
# SC419949                     7.726939         7       5.0  5.195021      2.0
# SC440783                     7.726939         1       5.0  3.000000      5.0
# SC578050                     7.726939         7       9.0  5.195021      9.0
#
#                ScoreC1  MeanTotalGHG        MeanCO2  MeanCH4      MeanN2O  \
# CompanyNumber
# 00019457           9.0      122937.8  110754.621875    319.9  5781.643750
# 00024869           9.0         305.1     268.003125      1.0     0.946875
# 00029559           2.0        2288.1    2144.109375      9.1    10.868750
# 00030226           2.0      122937.8  110754.621875    319.9  5781.643750
# 00033774           1.0      122937.8  110754.621875    319.9  5781.643750
# ...                ...           ...            ...      ...          ...
# SC334329           5.0         305.1     268.003125      1.0     0.946875
# SC367563           6.0        3310.9    3179.271875     10.5    20.143750
# SC419949           6.0         305.1     268.003125      1.0     0.946875
# SC440783           3.0      122937.8  110754.621875    319.9  5781.643750
# SC578050           8.0       15214.9   12694.615625     46.3    97.940625
#
#                    MeanHFC    MeanPFC  MeanNF3     MeanSF6  GHGIntensity  \
# CompanyNumber
# 00019457       5166.559375  410.50625      0.3  504.234375      0.814688
# 00024869         35.025000    0.08125      0.0    0.000000      0.000000
# 00029559        100.643750    0.11875      0.0   23.209375      0.022500
# 00030226       5166.559375  410.50625      0.3  504.234375      0.814688
# 00033774       5166.559375  410.50625      0.3  504.234375      0.814688
# ...                    ...        ...      ...         ...           ...
# SC334329         35.025000    0.08125      0.0    0.000000      0.000000
# SC367563        100.806250    0.14375      0.0    0.000000      0.049375
# SC419949         35.025000    0.08125      0.0    0.000000      0.000000
# SC440783       5166.559375  410.50625      0.3  504.234375      0.814688
# SC578050       2376.128125    0.00000      0.0    0.000000      0.083125
#
#                CO2Intensity       PM10       PM25          CO       NMVOC  \
# CompanyNumber
# 00019457           0.724688  42.680938  32.870906  632.933031  409.348156
# 00024869           0.000000   0.032344   0.027031    2.050844    0.366812
# 00029559           0.020938   0.372188   0.322406   22.857313    4.384531
# 00030226           0.724688  42.680938  32.870906  632.933031  409.348156
# 00033774           0.724688  42.680938  32.870906  632.933031  409.348156
# ...                     ...        ...        ...         ...         ...
# SC334329           0.000000   0.032344   0.027031    2.050844    0.366812
# SC367563           0.047813   1.115719   0.997531   50.637906    8.058969
# SC419949           0.000000   0.032344   0.027031    2.050844    0.366812
# SC440783           0.724688  42.680938  32.870906  632.933031  409.348156
# SC578050           0.070313   4.089688   3.473219  106.895281   86.132250
#
#                 Benzene  Butadine  EnergyIntensity  Electricity  \
# CompanyNumber
# 00019457       3.675875     0.593              2.6         1.81
# 00024869       0.015906     0.003              6.2         0.78
# 00029559       0.180562     0.039              1.6         0.88
# 00030226       3.675875     0.593              2.6         1.81
# 00033774       3.675875     0.593              2.6         1.81
# ...                 ...       ...              ...          ...
# SC334329       0.015906     0.003              6.2         0.78
# SC367563       0.377531     0.090              2.6         1.44
# SC419949       0.015906     0.003              6.2         0.78
# SC440783       3.675875     0.593              2.6         1.81
# SC578050       0.889250     0.241              3.7         2.48
#
#                Petrol/diesel  Natural gas  OtherEenergy  EnergyTotal  \
# CompanyNumber
# 00019457                0.69         0.83          9.38        12.70
# 00024869                0.17         0.07          0.01         1.03
# 00029559                1.12         0.17          0.08         2.25
# 00030226                0.69         0.83          9.38        12.70
# 00033774                0.69         0.83          9.38        12.70
# ...                      ...          ...           ...          ...
# SC334329                0.17         0.07          0.01         1.03
# SC367563                3.47         0.42          0.35         5.69
# SC419949                0.17         0.07          0.01         1.03
# SC440783                0.69         0.83          9.38        12.70
# SC578050                3.52         1.90          1.90         9.74
#
#                 S1S2CO2e
# CompanyNumber
# 00019457           47.63
# 00024869          269.00
# 00029559       219927.00
# 00030226        39186.00
# 00033774       431311.00
# ...                  ...
# SC334329            0.00
# SC367563         2272.20
# SC419949          771.00
# SC440783        12715.00
# SC578050          123.00
#
# [765 rows x 38 columns]

# %%
scaler = MinMaxScaler()
normalised_df_regression = scaler.fit_transform(df_regression_2)
S1S2CO2e = normalised_df_regression[:, -1]

# drop the label
normalised_df_regression = np.delete(normalised_df_regression, -1, axis=1)

# %%
X = normalised_df_regression
Y = S1S2CO2e

X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.70, test_size=0.30, random_state=0)

print('Number of instances in X: {}'.format(np.shape(X)[0]))
print('Number of instances in X_train: {}'.format(X_train.shape[0]))
print('Number of instances in X_test: {}'.format(X_test.shape[0]))
print('Number of instances in X_train and X_test together: {}'.format(X_train.shape[0] + X_test.shape[0]))
# Out:
# Number of instances in X: 765
# Number of instances in X_train: 535
# Number of instances in X_test: 230
# Number of instances in X_train and X_test together: 765

# %%
rf_regressor = RandomForestRegressor()
rf_regressor.fit(X_train, y_train)
print('Training accuracy: {:.3f}'.format(rf_regressor.score(X_train, y_train)))

print('Testing accuracy by using score function: {:.3f}'.format(rf_regressor.score(X_test, y_test)))
print('Testing accuracy by using r2_score meric: {:.3f}'.format(r2_score(y_test, rf_regressor.predict(X_test))))
# Out:
# Training accuracy: 0.902
# Testing accuracy by using score function: 0.436
# Testing accuracy by using r2_score meric: 0.436

# %%
# perform 10-fold cross-validation
cv_scores = cross_val_score(rf_regressor, X_train, y_train, cv=10)

# print the cross-validation scores
print('Cross-validation scores: ', cv_scores)

# print the mean of the cross-validation scores
print('Mean cross-validation score: {:.3f}'.format(np.mean(cv_scores)))
# Out:
# Cross-validation scores:  [ 0.46772591  0.48636848  0.77589716  0.25891939  0.34060132 -0.12231908
#  -0.05055186  0.48477801  0.26862918  0.23269643]
# Mean cross-validation score: 0.314

# %%
# Define the number of folds for cross-validation
n_folds = 10

# Initialize an empty list to store RMSE scores for each fold
rmse_scores = []
r2_scores = []

# Create the KFold cross-validator
kfold = KFold(n_splits=n_folds, shuffle=False)

# Perform 10-fold cross-validation
for train_idx, test_idx in kfold.split(X):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = Y[train_idx], Y[test_idx]
    
    # Create and train the model
    rf_regressor.fit(X_train, y_train)
    
    # Evaluate the model on the test set and calculate RMSE
    y_pred = rf_regressor.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    rmse_scores.append(rmse)
    r2_scores.append(r2)

# Convert the RMSE scores to a NumPy array for easier calculations
rmse_scores = np.array(rmse_scores)
r2_scores = np.array(r2_scores)

# Calculate the mean and standard deviation of RMSE scores
mean_rmse = np.mean(rmse_scores)
std_rmse = np.std(rmse_scores)
mean_r2 = np.mean(r2_scores)
std_r2 = np.std(r2_scores)

print('10-Fold Cross-Validation RMSE Scores:')
print(rmse_scores)
print('Mean RMSE: {:.3f}'.format(mean_rmse))
print('Standard Deviation of RMSE: {:.3f}'.format(std_rmse))

print('10-Fold Cross-Validation R2 Scores:')
print(r2_scores)
print('Mean R2: {:.3f}'.format(mean_r2))
print('Standard Deviation of R2: {:.3f}'.format(std_r2))
# Out:
# 10-Fold Cross-Validation RMSE Scores:
# [0.16543898 0.09406679 0.14097273 0.12510273 0.1454024  0.0978714
#  0.04005512 0.07378804 0.06777141 0.06093456]
# Mean RMSE: 0.101
# Standard Deviation of RMSE: 0.039
# 10-Fold Cross-Validation R2 Scores:
# [ 0.19315536  0.52252195  0.12777267  0.37205241  0.50636921  0.40951982
#  -0.76662402  0.56148556  0.41550188  0.77846731]
# Mean R2: 0.312
# Standard Deviation of R2: 0.400

# %%
# make predictions on the test set
y_pred = rf_regressor.predict(X_test)

# calculate the RMSE
rmse = mean_squared_error(y_test, y_pred, squared=False)
print('Root Mean Squared Error: {:.3f}'.format(rmse))
# Out:
# Root Mean Squared Error: 0.128

# %%
features_list = df_regression_2.columns

# %%
# summarise feature importance
for i,v in enumerate(rf_regressor.feature_importances_):
    print(f"Feature: {features_list[i]}, Score: {v}")

# plot feature importance
plt.bar([x for x in range(len(rf_regressor.feature_importances_))], rf_regressor.feature_importances_)

plt.show()
# Out:
# Feature: AssetsM, Score: 0.19651498812383664
# Feature: TurnoverM, Score: 0.2289969010032205
# Feature: FTE, Score: 0.14841605282032103
# Feature: IR_CO2ePerAssetsM, Score: 0.022548581796216945
# Feature: IR_CO2ePerTurnoverM, Score: 0.101183170627229
# Feature: IR_CO2ePerFTE, Score: 0.07385723870567364
# Feature: DefraRatio, Score: 0.030023783879060843
# Feature: NormalisedIrCO2ePerAssetsM, Score: 0.0
# Feature: NormalisedIrCO2ePerTurnoverM, Score: 0.0
# Feature: NormalisedIrCO2ePerFTE, Score: 0.0
# Feature: ScoreC1a, Score: 0.004646101159757009
# Feature: ScoreC1t, Score: 0.006638101511268807
# Feature: ScoreC1f, Score: 0.028894601069471563
# Feature: ScoreC2, Score: 0.01046162504540435
# Feature: ScoreC1, Score: 0.020564744908946393
# Feature: MeanTotalGHG, Score: 0.00273081502962373
# Feature: MeanCO2, Score: 0.002005786396134988
# Feature: MeanCH4, Score: 0.003454699867334162
# Feature: MeanN2O, Score: 0.004155284893457989
# Feature: MeanHFC, Score: 0.020873916068542414
# Feature: MeanPFC, Score: 0.01045233111301076
# Feature: MeanNF3, Score: 0.0026924483551279965
# Feature: MeanSF6, Score: 0.008974949538087916
# Feature: GHGIntensity, Score: 0.006649993316158156
# Feature: CO2Intensity, Score: 0.0017447783266968434
# Feature: PM10, Score: 0.005967892107836652
# Feature: PM25, Score: 0.0023444999657563333
# Feature: CO, Score: 0.004380274861048531
# Feature: NMVOC, Score: 0.006535393477745369
# Feature: Benzene, Score: 0.0046602269877073
# Feature: Butadine, Score: 0.007120706920439742
# Feature: EnergyIntensity, Score: 0.005284459418683567
# Feature: Electricity, Score: 0.002111576137843332
# Feature: Petrol/diesel, Score: 0.005946503894757248
# Feature: Natural gas, Score: 0.008473713295814285
# Feature: OtherEenergy, Score: 0.006512565733324372
# Feature: EnergyTotal, Score: 0.004181293644461662

# %%
y_pred_train = rf_regressor.predict(X_train)
y_pred_combined = np.concatenate((y_pred_train, y_pred), axis=0)
y_pred_combined.shape
# Out:
# (765,)

# %%
y_pred_combined_2d = y_pred_combined.reshape(-1, 1)
y_pred_combined_2d.shape
# Out:
# (765, 1)

# %%
# Append y_pred to the normalised_score_table
combined_table = np.hstack((normalised_df_regression, y_pred_combined_2d))

# Inverse transform the combined table
inverse_transformed_table = scaler.inverse_transform(combined_table)

# Extract the inverse transformed y_pred
inverse_transformed_y_pred = inverse_transformed_table[:, -1]

# %%
inverse_transformed_y_pred_series = pd.Series(inverse_transformed_y_pred)
inverse_transformed_y_pred_series.describe()
# Out:
# count       765.000000
# mean      21217.818332
# std       47245.994687
# min           2.424707
# 25%         371.834068
# 50%        2032.480420
# 75%       14737.715900
# max      344696.190170
# dtype: float64

# %%
X = normalised_df_regression
Y = S1S2CO2e

X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.70, test_size=0.30, random_state=0)

print('Number of instances in X: {}'.format(np.shape(X)[0]))
print('Number of instances in X_train: {}'.format(X_train.shape[0]))
print('Number of instances in X_test: {}'.format(X_test.shape[0]))
print('Number of instances in X_train and X_test together: {}'.format(X_train.shape[0] + X_test.shape[0]))
# Out:
# Number of instances in X: 765
# Number of instances in X_train: 535
# Number of instances in X_test: 230
# Number of instances in X_train and X_test together: 765

# %%
X_train.shape
# Out:
# (535, 37)
